# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('../input/bank-customer-segmentation/bank_transactions.csv')

# %%
df.head(5)

# %%
len(df['CustLocation'].unique())

# %% [markdown]
# Gender Analysis:
# - Population Split
# - Are transaction amounts by one group higher? Or more frequent?
# - Does one group make transac during a particular time of day? Or particular season?
#
# Location Analysis:
# - Population Split
# - Are transaction amounts by one group higher? Or more frequent?
# - Does one group make transac during a particular time of day? Or particular season?
#
# Age Analysis:
# - Age KDE plot
# - Same q's

# %% [markdown]
# # Age Analysis

# %%
df2 = df[:30].copy()

# %%
df2['CustomerDOB'] = pd.to_datetime(df2['CustomerDOB'])

# %%
df2['CustomerDOB']

# %%
sns.set_style("white")
a = sns.kdeplot(df[df.CustAge], color = '#1a5d57', shade = True, alpha = 0.9, linewidth = 1.5, edgecolor = 'black')
for j in ['right', 'left', 'top']:
    a.spines[j].set_visible(False)
    a.spines['bottom'].set_linewidth(1.2)

fig.tight_layout(h_pad = 3)
plt.show()
